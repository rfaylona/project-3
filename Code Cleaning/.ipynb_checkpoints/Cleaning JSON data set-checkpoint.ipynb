# %%
import pandas as pd

# %%
df = pd.read_json('yelp_academic_dataset_tip.json', lines=True)

df.head()
# Out:
#                   user_id             business_id  \
# 0  WCjg0jdHXMlwbqS9tZUx8Q  ENwBByjpoa5Gg7tKgxqwLg
# 1  42-Z02y9bABShAGZhuSzrQ  jKO4Og6ucdX2-YCTKQVYjg
# 2  5u7E3LYp_3eB8dLuUBazXQ  9Bto7mky640ocgezVKSfVg
# 3  wDWoMG5N9oI4DJ-p7z8EBg  XWFjKtRGZ9khRGtGg2ZvaA
# 4  JmuFlorjjRshHTKzTwNtgg  mkrx0VhSMU3p3uhyJGCoWA
#
#                                                 text                date  \
# 0                               Carne asada chips... 2011-07-22 19:07:35
# 1  Best happy hour from 3pm to 6pm! $1 off martin... 2014-09-10 07:33:29
# 2  Nice people, skilled staff, clean location - b... 2013-12-13 23:23:41
# 3  1/2-price bowling & the "Very" Old Fashion are... 2017-07-11 23:07:16
# 4  Solid gold's. Great sauna. Great staff, too. E... 2016-11-30 08:46:36
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
clean_df = df.dropna(how='all')

# %%
# 2019-2021

dated_df = pd.to_datetime(df["date"])
sorted_df = df.sort_values(["date"], ascending= False)
sorted_df.head()
# Out:
#                         user_id             business_id  \
# 669130   q4YuIIWaekF_lrYFCG440A  I2OblwJG8_XzFxxoHU0vVQ
# 820468   63UoTNVbHn35th-pgp6UKw  vQ0ihvqI0Xpz8TxBIKK_qg
# 508765   Ouz4R8N4pDyYBqML6zb-ZA  7rEr-_j7NT2YZMFIi3KdpA
# 656329   Q_fbXeB2HyRg6CmctrICKw  wegBPIo-9hnuEtAaY2xYvw
# 1148517  eseZ_gMjqBQMtyHyPpDMLA  t5EgwRXG6MZSihdqugOSKg
#
#                                                       text  \
# 669130   Surgeries are only completed on Thursdays only...
# 820468       Best donuts in town. Staff is super friendly.
# 508765              Temporarily closed today due to covid.
# 656329   Try the chocolate cookie-ice cream sandwich.  ...
# 1148517                                        Great place
#
#                        date  compliment_count
# 669130  2021-01-28 14:20:15                 0
# 820468  2021-01-28 14:11:48                 0
# 508765  2021-01-28 14:01:20                 0
# 656329  2021-01-28 13:26:55                 0
# 1148517 2021-01-28 11:57:22                 0

# %%
relevant_df = sorted_df[sorted_df['date'] > "2019-1-1"]
relevant_df
# Out:
#                         user_id             business_id  \
# 669130   q4YuIIWaekF_lrYFCG440A  I2OblwJG8_XzFxxoHU0vVQ
# 820468   63UoTNVbHn35th-pgp6UKw  vQ0ihvqI0Xpz8TxBIKK_qg
# 508765   Ouz4R8N4pDyYBqML6zb-ZA  7rEr-_j7NT2YZMFIi3KdpA
# 656329   Q_fbXeB2HyRg6CmctrICKw  wegBPIo-9hnuEtAaY2xYvw
# 1148517  eseZ_gMjqBQMtyHyPpDMLA  t5EgwRXG6MZSihdqugOSKg
# ...                         ...                     ...
# 431164   K-2-4KsCg_fEvc7xrS5yyA  viqkunBBI6QOIZehME-7gg
# 399487   TSHoVpWNd-mwjAw_kkSOfQ  zmRHDJq8qgWoVYobHL2ggg
# 435268   aBQZ_rREkyaQRpH9XjnjSA  tUhIIaYSjBuSbJzcf6CGIg
# 952571   bMGIATKbYqPu8lkyLirvBw  bORoF6fOYu39jHgzNyiKiA
# 1005768  yd9N1h-A8SrMnh6HtqHXiA  KAD2Vk1_qXX_utyv8Ndsow
#
#                                                       text  \
# 669130   Surgeries are only completed on Thursdays only...
# 820468       Best donuts in town. Staff is super friendly.
# 508765              Temporarily closed today due to covid.
# 656329   Try the chocolate cookie-ice cream sandwich.  ...
# 1148517                                        Great place
# ...                                                    ...
# 431164                                               Great
# 399487   Go buy an Android. This mall kiosk is a joke. ...
# 435268                  Good stuff,  always fresh and hot!
# 952571   The bathroom doors aren't marked! The Japanese...
# 1005768  Not a lot of good to say.  Limited menu. Limit...
#
#                        date  compliment_count
# 669130  2021-01-28 14:20:15                 0
# 820468  2021-01-28 14:11:48                 0
# 508765  2021-01-28 14:01:20                 0
# 656329  2021-01-28 13:26:55                 0
# 1148517 2021-01-28 11:57:22                 0
# ...                     ...               ...
# 431164  2019-01-01 00:35:54                 0
# 399487  2019-01-01 00:31:17                 0
# 435268  2019-01-01 00:27:50                 0
# 952571  2019-01-01 00:15:42                 0
# 1005768 2019-01-01 00:05:28                 0
#
# [97480 rows x 5 columns]

# %%
business_df = pd.read_json('yelp_academic_dataset_business.json', lines=True)

business_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-720e8b32b1e9> in <module>
# ----> 1 business_df = pd.read_json('yelp_academic_dataset_business.json', lines=True)
#       2
#       3 business_df.head()
#
# NameError: name 'pd' is not defined
