# %%
import pandas as pd
import json
import pprint
from datetime import datetime as dt
from pandas import DataFrame
import time

# %%
with open ('yelp_merged_db.json', 'r') as file:
    data = json.load(file)

data
# Out:
# {'business_id': {'0': 'tCbdrRPZA0oiIYSmHG3J0w',
#   '1': 'bvN78flM8NLprQ1a1y5dRg',
#   '2': 'DLbEQySMW3X7KvkybpEYkw',
#   '3': 'j68RDnvOaYEwGcY9cTEHpA',
#   '4': 'j68RDnvOaYEwGcY9cTEHpA',
#   '5': 'j68RDnvOaYEwGcY9cTEHpA',
#   '6': '_bZOUUc6Sr_W3BxbOUJacw',
#   '7': 'uMGsjQGT35rX4AAt1Hp9og',
#   '8': 'uMGsjQGT35rX4AAt1Hp9og',
#   '9': 'jx91IMdGOmLOo8h_F9z39g',
#   '10': 'J0qv-BVQKQwImRZQ1_ZKdQ',
#   '11': '5PsApTz-WqhF_-8mfqGtGw',
#   '12': 'sSX4BXohwSfMJVhHn4nh2w',
#   '13': 'G6xF2EGY-F04iFhq5sX8MQ',
#   '14': 'xqBjjE3lsBWCEj1CulMGSg',
#   '15': 'Npm0cjoyWwyV13OULL9qOA',
#   '16': 'HMXiuCxHDXqMH1hBpaHd9g',
#   '17': 'ZA3u0Nu5V6TqkcYh8U0zdg',
#   '18': 'CBkF_Ub_nxOhOEN3Zbo_RQ',
#   '19': 'CBkF_Ub_nxOhOEN3Zbo_RQ',
#   '20': 'aTAe3uMYBEwU0FbTMFEI5g',
#   '21': '52f_ztOVodIoV43Qt-R4rA',
#   '22': 'jyb-bKcBJUVlB8LABv3X9Q',
#   '23': 'BGLqNLxH8p3dEoiLVLRq1A',
#   '24': 'voim57uVEODiIADpDZ_Eng',
#   '25': 'fQQMzZs2oF3mIse1rAYhVA',
#   '26': 'vhkMPYcKXznnHNkSWfF4kQ',
# ...

# %%
# Json file that is easier to work with is 

df = pd.read_json('yelp_merged_db.json', lines=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-020253b18c1b> in <module>
# ----> 1 df = pd.read_json('yelp_merged_db.json', lines=True)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
# ...
